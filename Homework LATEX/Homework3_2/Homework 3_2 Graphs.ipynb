# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Polygon

from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)

# %%
def funct(x):
    y = (1 / (statdev * np.sqrt(2 * np.pi))) * np.exp(-((x - mean) ** 2 / (2 * variance)))
    return y


mean = 200
statdev = 15
variance = statdev ** 2
# Range factor
factor = 3.4

a, b = 190, 200

x = np.linspace(a - statdev * factor, b + statdev * factor, 10000)
y = funct(x)
    
fig, ax = plt.subplots()
ax.plot(x, y, 'k')
ax.set_ylim(bottom=0)

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Shaded Region (More Effective Method)
# xfill = np.linspace(a - statdev * factor, b + statdev * factor, 10000)
# ax.fill_between(xfill, y, 0, where=(x > a) & (x <= b), color='teal', alpha='0.6')

ax.set_xticks([mean])

plt.axvline(x=mean, color='k', linestyle='-.', linewidth=0.5, ymax=0.95)

ax.text(220, 0.025, '$\sigma = {}$ millimeters'.format(statdev))

ax.set_title(r'Drink Volume Normal Distribution Plot')
ax.set_xlabel(r'Drink Volume (millimeters)')

plt.savefig('problem1.pdf')

plt.show()

# %%
def funct(x):
    y = (1 / (statdev * np.sqrt(2 * np.pi))) * np.exp(-((x - mean) ** 2 / (2 * variance)))
    return y


mean = 24
statdev = 3.8
variance = statdev ** 2
# Range factor
factor = 2.2

a, b = 16, 30

x = np.linspace(a - statdev * factor, b + statdev * factor, 10000)
y = funct(x)
    
fig, ax = plt.subplots()
ax.plot(x, y, 'k')
ax.set_ylim(bottom=0)

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Shaded Region (More Effective Method)
# xfill = np.linspace(a - statdev * factor, b + statdev * factor, 10000)
# ax.fill_between(xfill, y, 0, where=(x > a) & (x <= b), color='teal', alpha='0.6')

ax.set_xticklabels(['{} minutes or 9:09 A.M.'.format(mean)])
ax.set_xticks([mean])

plt.axvline(x=mean, color='k', linestyle='-.', linewidth=0.5, ymax=0.95)

ax.text(7, 0.1, '$\sigma = {}$ minutes'.format(statdev))

ax.set_title(r'Arrival Time Normal Distribution Plot')
ax.set_xlabel(r'Arrival Time (minutes)')

plt.savefig('problem2.pdf')

plt.show()

# %%
def funct(x):
    y = (1 / (statdev * np.sqrt(2 * np.pi))) * np.exp(-((x - mean) ** 2 / (2 * variance)))
    return y


mean = 9.25
statdev = 0.60
variance = statdev ** 2
# Range factor
factor = 2.2

a, b = 5, 15

x = np.linspace(a - statdev * factor, b + statdev * factor, 10000)
y = funct(x)
    
fig, ax = plt.subplots()
ax.plot(x, y, 'k')
ax.set_ylim(bottom=0)

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Shaded Region (More Effective Method)
# xfill = np.linspace(a - statdev * factor, b + statdev * factor, 10000)
# ax.fill_between(xfill, y, 0, where=(x > a) & (x <= b), color='teal', alpha='0.6')

ax.set_xticklabels(['${}$'.format('\${}'.format(mean))])
ax.set_xticks([mean])

plt.axvline(x=mean, color='k', linestyle='-.', linewidth=0.5, ymax=0.95)

ax.text(4, 0.60, '$\sigma = {}$'.format('\${}'.format(statdev)))
                                       
ax.set_title(r'Hourly Wages Normal Distribution Plot')
ax.set_xlabel(r'Hourly Wages')

plt.savefig('problem3.pdf')

plt.show()

# %%
def funct(x):
    y = (1 / (statdev * np.sqrt(2 * np.pi))) * np.exp(-((x - mean) ** 2 / (2 * variance)))
    return y


mean = 0
statdev = 1
variance = statdev ** 2
# Range factor
factor = 2.2

a, b = -1, 1

x = np.linspace(a - statdev * factor, b + statdev * factor, 10000)
y = funct(x)
    
fig, ax = plt.subplots()
ax.plot(x, y, 'k')
ax.set_ylim(bottom=0)

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Shaded Region (More Effective Method)
# xfill = np.linspace(a - statdev * factor, b + statdev * factor, 10000)
# ax.fill_between(xfill, y, 0, where=(x > a) & (x <= b), color='teal', alpha='0.6')

ax.set_xticklabels(['$\mu$'])
ax.set_xticks([mean])

plt.axvline(x=mean, color='k', linestyle='-.', linewidth=0.5, ymax=0.95)

ax.text(1, 0.35, '$\sigma = {}$'.format(statdev))

ax.set_title(r'Normal Distribution Plot')
ax.set_xlabel(r'Units ($\sigma$)')

plt.savefig('problem4.pdf')

plt.show()

# %%
def funct(x):
    y = (1 / (statdev * np.sqrt(2 * np.pi))) * np.exp(-((x - mean) ** 2 / (2 * variance)))
    return y


mean = 10
statdev = 2
variance = statdev ** 2
# Range factor
factor = 3.4

a, b = 6, 14

x = np.linspace(a - statdev * factor, b + statdev * factor, 10000)
y = funct(x)
    
fig, ax = plt.subplots()
ax.plot(x, y, 'k')
ax.set_ylim(bottom=0)

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Shaded Region (More Effective Method)
# xfill = np.linspace(a - statdev * factor, b + statdev * factor, 10000)
# ax.fill_between(xfill, y, 0, where=(x > a) & (x <= b), color='teal', alpha='0.6')

ax.set_xticks([mean])

plt.axvline(x=mean, color='k', linestyle='-.', linewidth=0.5, ymax=0.95)

ax.text(14, 0.17, '$\sigma = {}$ years'.format(statdev))

ax.set_title(r'Motor Lifetime Normal Distribution Plot')
ax.set_xlabel(r'Lifetime (years)')

plt.savefig('problem5.pdf')

plt.show()

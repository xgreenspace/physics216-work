# %% [markdown]
# # Creating a Histogram in Python

# %%
import csv
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Polygon

from matplotlib import rc
rc('font',**{'family':'sans-serif','sans-serif':['Helvetica']})
## for Palatino and other serif fonts use:
#rc('font',**{'family':'serif','serif':['Palatino']})
rc('text', usetex=True)

# %% [markdown]
# ## Sample Histogram
#
# Basic Histogram showing the frequency of the diameter of peanuts.

# %%
with open('peanut.csv', 'r') as csv_file:
    
    csv_reader = csv.reader(csv_file, delimiter = ',')
    line_count = 0
    sampleNo = []
    major = []
    minor = []
    for row in csv_reader:
        if line_count == 0:
            line_count += 1
        else:
            sampleNo.append(row[0])
            major.append(float(row[1]))
            minor.append(float(row[2]))
            
n, bins, patches = plt.hist(x=major, bins=[10,12,14,16,18,20,22,24,26], edgecolor='black', color='maroon')
plt.xlabel('Major Diameter (mm)')
plt.ylabel('Frequency')
plt.title('Peanut Sample')
plt.show()

# %% [markdown]
# ## Plotting a Normal Distribution Curve and Area under Curve (Problem 1)
#
# - Using Probability Density Function
#
# I can use this plot for showing the graph for the next assignment

# %%
def funct(x):
    y = (1 / (statdev * np.sqrt(2 * np.pi))) * np.exp(-((x - mean) ** 2 / (2 * variance)))
    return y


mean = 800
statdev = 40
variance = statdev ** 2

a, b = 778, 834

x = np.linspace(a - statdev * 2.6, b + statdev * 2.6, 10000)
y = funct(x)
    
fig, ax = plt.subplots()
ax.plot(x, y, 'k')
ax.set_ylim(bottom=0)

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Shaded Region (More Effective Method)
xfill = np.linspace(a - statdev * 2.6, b + statdev * 2.6, 10000)
ax.fill_between(xfill, y, 0, where=(x > a) & (x <= b), color='teal', alpha='0.6')

ax.set_xticks((mean, a, b))

plt.axvline(x=mean, color='k', linestyle='-.', linewidth=0.5, ymax=0.95)

ax.text(900, 0.009, '$\sigma = 40$')

ax.set_title(r'Bulb Lifetime Normal Distribution Plot')
ax.set_xlabel(r'Burn Time (hours)')

plt.savefig('problem2.pdf')

plt.show()

# %% [markdown]
# ## Problem 2 Diagram

# %%
def funct(x):
    y = (1 / (statdev * np.sqrt(2 * np.pi))) * np.exp(-((x - mean) ** 2 / (2 * variance)))
    return y


mean = 3.0
statdev = 0.5
variance = statdev ** 2

a, b = 0, 2.3

x = np.linspace(a - statdev * 0, b + statdev * 5, 10000)
y = funct(x)
    
fig, ax = plt.subplots()
ax.plot(x, y, 'k')
ax.set_ylim(bottom=0)

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Shaded Region (More Effective Method)
xfill = np.linspace(a - statdev * 0, b + statdev * 5, 10000)
ax.fill_between(xfill, y, 0, where=(x > a) & (x <= b), color='orange', alpha='0.6')

ax.set_xticks((mean, a, b))

plt.axvline(x=mean, color='k', linestyle='-.', linewidth=0.5, ymax=0.95)

ax.text(3.5, 0.75, '$\sigma = 0.5$')

ax.set_title(r'Battery Lifetime Normal Distribution Plot')
ax.set_xlabel(r'Lifetime (years)')

plt.savefig('problem1.pdf')

plt.show()

# %% [markdown]
# ## Problem 3

# %%
def funct(x):
    y = (1 / (statdev * np.sqrt(2 * np.pi))) * np.exp(-((x - mean) ** 2 / (2 * variance)))
    return y


mean = 3.0
statdev = 0.005
variance = statdev ** 2

a, b = 2.99, 3.01

x = np.linspace(a - a * 0.005, b + b * 0.005, 10000)
y = funct(x)
    
fig, ax = plt.subplots()
ax.plot(x, y, 'k')
ax.set_ylim(bottom=0)

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Shaded Region (More Effective Method)
xfill = np.linspace(a - a * 0.005, b + b * 0.005, 10000)
ax.fill_between(xfill, y, 0, where=(x < a) | (x >= b), color='red', alpha='0.6')

ax.set_xticks((mean, a, b))

plt.axvline(x=mean, color='k', linestyle='-.', linewidth=0.5, ymax=0.95)

ax.text(3.015, 75, '$\sigma = 0.005$')

ax.set_title(r'Diameter of Ball Bearings Normal Distribution Plot')
ax.set_xlabel(r'Diameter (cm)')

plt.savefig('problem3.pdf')

plt.show()

# %%
def funct(x):
    y = (1 / (statdev * np.sqrt(2 * np.pi))) * np.exp(-((x - mean) ** 2 / (2 * variance)))
    return y


mean = 1.5
statdev = 0.2
variance = statdev ** 2

a, b = 1.108, 1.892

x = np.linspace(a - a * 0.5, b + b * 0.3, 10000)
y = funct(x)
    
fig, ax = plt.subplots()
ax.plot(x, y, 'k')
ax.set_ylim(bottom=0)

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Shaded Region (More Effective Method)
xfill = np.linspace(a - a * 0.5, b + b * 0.3, 10000)
ax.fill_between(xfill, y, 0, where=(x > a) & (x <= b), color='green', alpha='0.6')

ax.set_xticklabels((mean, '${} - d$'.format(mean), '${} + d$'.format(mean)))
ax.set_xticks((mean, a, b))

plt.axvline(x=mean, color='k', linestyle='-.', linewidth=0.5, ymax=0.95)

ax.text(1.8, 1.75, '$\sigma = 0.2$')

ax.set_title(r'Recorded Measurements Normal Distribution Plot')
ax.set_xlabel(r'Measurements')

plt.savefig('problem4.pdf')

plt.show()

# %% [markdown]
# ## Problem 5

# %%
def funct(x):
    y = (1 / (statdev * np.sqrt(2 * np.pi))) * np.exp(-((x - mean) ** 2 / (2 * variance)))
    return y


mean = 40
statdev = 2
variance = statdev ** 2

a, b = 43, 48

x = np.linspace(a - statdev * 10, b + statdev * 5, 10000)
y = funct(x)
    
fig, ax = plt.subplots()
ax.plot(x, y, 'k')
ax.set_ylim(bottom=0)

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Shaded Region (More Effective Method)
xfill = np.linspace(a - statdev * 10, b + statdev * 5, 10000)
ax.fill_between(xfill, y, 0, where=(x > a) & (x <= b), color='purple', alpha='0.6')

ax.set_xticks((mean, a))

plt.axvline(x=mean, color='k', linestyle='-.', linewidth=0.5, ymax=0.95)

ax.text(45, 0.175, '$\sigma = 2$')

ax.set_title(r'Resistance Normal Distribution Plot')
ax.set_xlabel(r'Resistance ($\Omega$)')

plt.savefig('problem5.pdf')

plt.show()

# %% [markdown]
# ## Problem 6

# %%
def funct(x):
    y = (1 / (statdev * np.sqrt(2 * np.pi))) * np.exp(-((x - mean) ** 2 / (2 * variance)))
    return y


mean = 74
statdev = 7
variance = statdev ** 2

a, b = 90, 100

x = np.linspace(a - statdev * 6, b + statdev * 1, 10000)
y = funct(x)
    
fig, ax = plt.subplots()
ax.plot(x, y, 'k')
ax.set_ylim(bottom=0)

plt.rc('text', usetex=True)
plt.rc('font', family='serif')

# Shaded Region (More Effective Method)
xfill = np.linspace(a - statdev * 6, b + statdev * 1, 10000)
ax.fill_between(xfill, y, 0, where=(x > a) & (x <= b), color='blue', alpha='0.6')
ax.fill_between(xfill, y, 0, where=(x > 0) & (x <= 80), color='red', alpha='0.6')

ax.set_xticks((mean, a))
ax.set_xticklabels((mean, '0.12'))

plt.axvline(x=mean, color='k', linestyle='-.', linewidth=0.5, ymax=0.95)

ax.text(90, 0.05, '$\sigma = 7$')

ax.set_title(r'Test Grades Normal Distribution Plot')
ax.set_xlabel(r'Grade')

plt.savefig('problem6.pdf')

plt.show()
